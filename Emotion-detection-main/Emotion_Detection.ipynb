# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras_preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "../Dataset/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 359 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "../Dataset/train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 359 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 8.8048 - accuracy: 0.2068
# Epoch 1: val_accuracy improved from -inf to 0.47266, saving model to best_model.h5
# 10/10 [==============================] - 10s 877ms/step - loss: 8.8048 - accuracy: 0.2068 - val_loss: 4.4404 - val_accuracy: 0.4727
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 3.3516 - accuracy: 0.5424
# Epoch 2: val_accuracy improved from 0.47266 to 0.67578, saving model to best_model.h5
# 10/10 [==============================] - 7s 731ms/step - loss: 3.3516 - accuracy: 0.5424 - val_loss: 1.9498 - val_accuracy: 0.6758
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 1.4961 - accuracy: 0.7125
# Epoch 3: val_accuracy improved from 0.67578 to 0.82031, saving model to best_model.h5
# 10/10 [==============================] - 7s 751ms/step - loss: 1.4961 - accuracy: 0.7125 - val_loss: 1.1817 - val_accuracy: 0.8203
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.9587 - accuracy: 0.8508
# Epoch 4: val_accuracy improved from 0.82031 to 0.91016, saving model to best_model.h5
# 10/10 [==============================] - 7s 726ms/step - loss: 0.9587 - accuracy: 0.8508 - val_loss: 0.3559 - val_accuracy: 0.9102
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.4397 - accuracy: 0.8915
# Epoch 5: val_accuracy improved from 0.91016 to 0.95703, saving model to best_model.h5
# 10/10 [==============================] - 7s 733ms/step - loss: 0.4397 - accuracy: 0.8915 - val_loss: 0.2275 - val_accuracy: 0.9570
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.9254
# Epoch 6: val_accuracy improved from 0.95703 to 0.96484, saving model to best_model.h5
# 10/10 [==============================] - 7s 728ms/step - loss: 0.3491 - accuracy: 0.9254 - val_loss: 0.1352 - val_accuracy: 0.9648
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.9356
# Epoch 7: val_accuracy improved from 0.96484 to 0.97656, saving model to best_model.h5
# 10/10 [==============================] - 7s 721ms/step - loss: 0.3074 - accuracy: 0.9356 - val_loss: 0.0672 - val_accuracy: 0.9766
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9661
# Epoch 8: val_accuracy did not improve from 0.97656
# 10/10 [==============================] - 7s 715ms/step - loss: 0.1822 - accuracy: 0.9661 - val_loss: 0.1142 - val_accuracy: 0.9570
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9695
# Epoch 9: val_accuracy improved from 0.97656 to 0.99609, saving model to best_model.h5
# 10/10 [==============================] - 7s 731ms/step - loss: 0.1039 - accuracy: 0.9695 - val_loss: 0.0146 - val_accuracy: 0.9961
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9831
# Epoch 10: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 7s 755ms/step - loss: 0.0626 - accuracy: 0.9831 - val_loss: 0.0259 - val_accuracy: 0.9844
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9695
# Epoch 11: val_accuracy improved from 0.99609 to 1.00000, saving model to best_model.h5
# 10/10 [==============================] - 7s 721ms/step - loss: 0.0823 - accuracy: 0.9695 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9864
# Epoch 12: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 7s 717ms/step - loss: 0.0541 - accuracy: 0.9864 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9763
# Epoch 13: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 7s 709ms/step - loss: 0.0609 - accuracy: 0.9763 - val_loss: 0.0068 - val_accuracy: 0.9961
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9864
# Epoch 14: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 7s 714ms/step - loss: 0.0314 - accuracy: 0.9864 - val_loss: 0.0414 - val_accuracy: 0.9883
# Epoch 14: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "../Dataset/test/hppy3.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 352ms/step
#  the image is of Surprise
