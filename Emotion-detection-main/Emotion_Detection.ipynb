# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras_preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )
#cố định model
for layer in base_model.layers:
  layer.trainable = False

# làm phẳng dữ liệu để đưa vào lớp dense
x = Flatten()(base_model.output)
#lớp mà mỗi neuron nhận đầu vào từ tất các neuron của lớp trước đó
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
#config model for training
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy'])

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "../Dataset/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 359 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "../Dataset/train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 359 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
#Stop training when a monitored metric has stopped improving.
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 12.8223 - accuracy: 0.2203
# Epoch 1: val_accuracy improved from -inf to 0.47656, saving model to best_model.h5
# 10/10 [==============================] - 9s 823ms/step - loss: 12.8223 - accuracy: 0.2203 - val_loss: 4.8055 - val_accuracy: 0.4766
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1010 - accuracy: 0.4441
# Epoch 2: val_accuracy improved from 0.47656 to 0.67188, saving model to best_model.h5
# 10/10 [==============================] - 7s 727ms/step - loss: 5.1010 - accuracy: 0.4441 - val_loss: 2.0360 - val_accuracy: 0.6719
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 2.2672 - accuracy: 0.6542
# Epoch 3: val_accuracy improved from 0.67188 to 0.75781, saving model to best_model.h5
# 10/10 [==============================] - 8s 771ms/step - loss: 2.2672 - accuracy: 0.6542 - val_loss: 1.4792 - val_accuracy: 0.7578
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 1.4929 - accuracy: 0.7627
# Epoch 4: val_accuracy improved from 0.75781 to 0.82422, saving model to best_model.h5
# 10/10 [==============================] - 8s 791ms/step - loss: 1.4929 - accuracy: 0.7627 - val_loss: 0.9997 - val_accuracy: 0.8242
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.7550 - accuracy: 0.8780
# Epoch 5: val_accuracy improved from 0.82422 to 0.94141, saving model to best_model.h5
# 10/10 [==============================] - 8s 773ms/step - loss: 0.7550 - accuracy: 0.8780 - val_loss: 0.2033 - val_accuracy: 0.9414
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9356
# Epoch 6: val_accuracy improved from 0.94141 to 0.95703, saving model to best_model.h5
# 10/10 [==============================] - 8s 769ms/step - loss: 0.2424 - accuracy: 0.9356 - val_loss: 0.1518 - val_accuracy: 0.9570
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.9288
# Epoch 7: val_accuracy did not improve from 0.95703
# 10/10 [==============================] - 7s 747ms/step - loss: 0.2647 - accuracy: 0.9288 - val_loss: 0.2435 - val_accuracy: 0.9570
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.8983
# Epoch 8: val_accuracy improved from 0.95703 to 0.96094, saving model to best_model.h5
# 10/10 [==============================] - 8s 765ms/step - loss: 0.4340 - accuracy: 0.8983 - val_loss: 0.1655 - val_accuracy: 0.9609
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9322
# Epoch 9: val_accuracy improved from 0.96094 to 0.99609, saving model to best_model.h5
# 10/10 [==============================] - 8s 788ms/step - loss: 0.2117 - accuracy: 0.9322 - val_loss: 0.0276 - val_accuracy: 0.9961
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9594
# Epoch 10: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 8s 784ms/step - loss: 0.0984 - accuracy: 0.9594 - val_loss: 0.0372 - val_accuracy: 0.9883
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9932
# Epoch 11: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0410 - accuracy: 0.9932 - val_loss: 0.0149 - val_accuracy: 0.9922
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9932
# Epoch 12: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 8s 782ms/step - loss: 0.0405 - accuracy: 0.9932 - val_loss: 0.0067 - val_accuracy: 0.9961
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9831
# Epoch 13: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 8s 774ms/step - loss: 0.0405 - accuracy: 0.9831 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9966
# Epoch 14: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 8s 770ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0051 - val_accuracy: 0.9961
# Epoch 14: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "../Dataset/test/hppy3.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 366ms/step
#  the image is of Happy
